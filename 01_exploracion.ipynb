# %% [markdown]
# # Proyecto Final — Predicción de resistencia antimicrobiana
#
# **Fase 1:** clasificación *resistente / sensible* a partir de datos genómicos.
#
# Este cuaderno es el punto de partida. Primero verificamos que el entorno funciona; luego cargaremos el primer conjunto de datos etiquetado y revisaremos el balance de clases.

# %% [markdown]
# ## 1. Verificación del entorno
#
# Si esta celda corre sin errores, las librerías clave están instaladas y el kernel apunta al entorno `amr-ml`.

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import xgboost

print('Python      :', sys.version.split()[0])
print('pandas      :', pd.__version__)
print('numpy       :', np.__version__)
print('scikit-learn:', sklearn.__version__)
print('xgboost     :', xgboost.__version__)
print('\nEntorno listo.')
# Out:
# Python      : 3.11.15
# pandas      : 3.0.3
# numpy       : 2.4.6
# scikit-learn: 1.9.0
# xgboost     : 3.2.0
#
# Entorno listo.

# %% [markdown]
# ## 2. Próximo paso: cargar el primer dataset
#
# Descarga de BV-BRC la tabla de fenotipos de resistencia de un organismo (por ejemplo *E. coli*) para un antibiótico, guárdala en una subcarpeta `data/` del repositorio, y cárgala aquí. El objetivo de este primer contacto es sencillo: mirar cuántas cepas son resistentes y cuántas sensibles (el balance de clases).

# %%
# TODO: ajustar la ruta al archivo descargado de BV-BRC
# df = pd.read_csv('data/ecoli_amr.csv')
# df.head()

# Cuando identifiques la columna de fenotipo (resistente/sensible),
# revisa el balance de clases:
# df['resistant_phenotype'].value_counts()
